# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# 1. Load dataset
dataset = pd.read_csv("Social_Network_Ads.csv")

# %%
# 2. Preprocess features
dataset["Gender"] = dataset["Gender"].map({"Male": 0, "Female": 1})
X = dataset.drop(columns=["User ID", "Purchased"])
y = dataset["Purchased"]

# %%
# 3. Train-test split
train_X, test_X, train_y, test_y = train_test_split(
    X, y, test_size=0.3, random_state=123, stratify=y
)

# %%
# 4. Feature scaling
sc = StandardScaler()
train_X = sc.fit_transform(train_X)
test_X = sc.transform(test_X)

# %%
# 5. Build model
model = Sequential([
    Dense(units=8, kernel_initializer='uniform', activation='relu', input_dim=3),
    Dense(units=6, kernel_initializer='uniform', activation='relu'),
    Dense(units=4, kernel_initializer='uniform', activation='relu'),
    Dense(units=1, kernel_initializer='uniform', activation='sigmoid')
])
# Out:
# d:\Deep_Learning\.venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# 6. Compile and train
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(train_X, train_y, validation_data=(test_X, test_y), epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.6429 - loss: 0.6926 - val_accuracy: 0.6417 - val_loss: 0.6920
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6429 - loss: 0.6915 - val_accuracy: 0.6417 - val_loss: 0.6907
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6429 - loss: 0.6902 - val_accuracy: 0.6417 - val_loss: 0.6894
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6429 - loss: 0.6888 - val_accuracy: 0.6417 - val_loss: 0.6882
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6429 - loss: 0.6875 - val_accuracy: 0.6417 - val_loss: 0.6867
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6429 - loss: 0.6860 - val_accuracy: 0.6417 - val_loss: 0.6850
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6429 - loss: 0.6842 - val_accuracy: 0.6417 - val_loss: 0.6830
# Epoch 8/50
# ...

# %%
# 7. Evaluate
predictions = model.predict(test_X)
predicted_classes = (predictions >= 0.5).astype(int).flatten()

print("Accuracy:", accuracy_score(test_y, predicted_classes))
print("Confusion Matrix:\n", confusion_matrix(test_y, predicted_classes))
print("Classification Report:\n", classification_report(test_y, predicted_classes))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Accuracy: 0.8916666666666667
# Confusion Matrix:
#  [[69  8]
#  [ 5 38]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91        77
#            1       0.83      0.88      0.85        43
#
#     accuracy                           0.89       120
#    macro avg       0.88      0.89      0.88       120
# weighted avg       0.89      0.89      0.89       120

# %%
import joblib

# Save the trained Keras model and the fitted scaler
model.save("social_ads_model.h5")
joblib.dump(sc, "scaler.pkl")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ['scaler.pkl']
